# %% [markdown]
# <a href="https://colab.research.google.com/github/JakePoirier/Machine-Learning/blob/main/HW2/data_prep_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df[numerical_cols + [target]].corr(method='pearson')

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

plt.figure(figsize=(6,4))
sns.histplot(df['session_duration'], kde=True)
plt.title('Distribution of Session Duration')
plt.xlabel('Session Duration')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(6,4))
sns.histplot(df['failed_logins'], kde=True)
plt.title('Distribution of Failed Logins')
plt.xlabel('Failed Logins')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(6,4))
sns.scatterplot(x='ip_reputation_score', y='attack_detected', data=df, alpha=0.4)
plt.title('IP Reputation Score vs. Attack Detected')
plt.xlabel('IP Reputation Score')
plt.ylabel('Attack Detected')
plt.show()
